# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.array([2,4,8,16,32,64])
iteration_num = np.array([20, 243, 854, 3204, 2992, 10541])

# %%
plt.plot(X, iteration_num, c='b', )
plt.grid()
plt.xlabel("|X|")
plt.ylabel("t")
plt.show()
